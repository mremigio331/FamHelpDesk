# %%
import testing_utils  # This sets up the import paths automatically
from models.user_profile import UserProfile, ProfileColorOptions
from pynamodb.exceptions import DoesNotExist
from aws_lambda_powertools import Logger
import random

# %%
profile = UserProfile.get(
                UserProfile.create_pk("08e17370-10d1-70ac-7119-105c0a0cfcfc"), UserProfile.create_sk()
            )
# Out:
# ---------------------------------------------------------------------------
# DoesNotExist                              Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 profile = UserProfile.get(
#       2                 UserProfile.create_pk("08e17370-10d1-70ac-7119-105c0a0cfcfc"), UserProfile.create_sk()
#       3             )
#
# File /opt/anaconda3/lib/python3.12/site-packages/pynamodb/models.py:555, in Model.get(cls, hash_key, range_key, consistent_read, attributes_to_get)
#     553     if item_data:
#     554         return cls.from_raw_data(item_data)
# --> 555 raise cls.DoesNotExist()
#
# DoesNotExist: Item does not exist

# %%
profile

# %%
profile.user_id
# Out:
# '08e17370-10d1-70ac-7119-105c0a0cfcfc'

# %%
ProfileColorOptions
# Out:
# <enum 'ProfileColorOptions'>

# %%
colors = [c.value for c in ProfileColorOptions]

# %%
random.choice(colors)
# Out:
# 'Green'
