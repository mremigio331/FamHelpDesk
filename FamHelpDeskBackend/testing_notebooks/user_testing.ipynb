# %%
import testing_utils  # This sets up the import paths automatically
from models.user_profile import UserProfile
from pynamodb.exceptions import DoesNotExist
from aws_lambda_powertools import Logger

# %%
profile = UserProfile.get(
                UserProfile.create_pk("08e17370-10d1-70ac-7119-105c0a0cfcfc"), UserProfile.create_sk()
            )

# %%
profile
# Out:
# UserProfile(display_name='Matt', nick_name='Matt', pk='USER_PROFILE#08e17370-10d1-70ac-7119-105c0a0cfcfc', provider='Cognito', sk='META', user_id='08e17370-10d1-70ac-7119-105c0a0cfcfc')

# %%
profile.user_id
# Out:
# '08e17370-10d1-70ac-7119-105c0a0cfcfc'
